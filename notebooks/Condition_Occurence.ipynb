# %% [markdown]
# # Condition Occurence Mapping

# %% [markdown]
# This is an attempt at mapping FHIR to OMOP using the following guide: https://build.fhir.org/ig/HL7/cdmh/profiles.html#omop-to-fhir-mappings
# In this notebook we are mapping FHIR to the OMOP Provider Table

# %% [markdown]
# # Load Data Frame from Parquet Catalog File

# %%
from pyspark.sql import SparkSession

from pyspark.sql.functions import dayofmonth,month,year,to_date,trunc,split,explode,array,col


# Create a local Spark session
spark = SparkSession.builder.appName('etl').getOrCreate()

# Read in our data
df = spark.read.parquet('catalog.parquet')

# %%
df.printSchema()
# Out:
# root
#  |-- occurrenceDateTime: string (nullable = true)
#  |-- vid: long (nullable = true)
#  |-- documentStatus: string (nullable = true)
#  |-- resourceType: string (nullable = true)
#  |-- lockEndTs: long (nullable = true)
#  |-- primarySource: boolean (nullable = true)
#  |-- id: string (nullable = true)
#  |-- meta: struct (nullable = true)
#  |    |-- lastUpdated: string (nullable = true)
#  |    |-- versionId: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- vaccineCode: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- encounter: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- patient: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- location: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- claim: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- provider: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- insurance: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- coverage: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |    |-- focal: boolean (nullable = true)
#  |    |    |-- sequence: long (nullable = true)
#  |-- identifier: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- system: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |    |    |-- type: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |-- use: string (nullable = true)
#  |    |    |-- period: struct (nullable = true)
#  |    |    |    |-- start: string (nullable = true)
#  |    |    |-- assigner: struct (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |    |-- extension: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |-- outcome: string (nullable = true)
#  |-- total: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |-- double: double (nullable = true)
#  |    |    |    |    |    |-- long: long (nullable = true)
#  |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- currency: string (nullable = true)
#  |    |    |-- value: struct (nullable = true)
#  |    |    |    |-- double: double (nullable = true)
#  |    |    |    |-- long: long (nullable = true)
#  |-- payment: struct (nullable = true)
#  |    |-- amount: struct (nullable = true)
#  |    |    |-- currency: string (nullable = true)
#  |    |    |-- value: struct (nullable = true)
#  |    |    |    |-- double: double (nullable = true)
#  |    |    |    |-- long: long (nullable = true)
#  |-- referral: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- billablePeriod: struct (nullable = true)
#  |    |-- start: string (nullable = true)
#  |    |-- end: string (nullable = true)
#  |-- contained: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- requester: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- performer: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- subject: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- intent: string (nullable = true)
#  |    |    |-- resourceType: string (nullable = true)
#  |    |    |-- status: string (nullable = true)
#  |    |    |-- payor: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- beneficiary: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- type: struct (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |-- use: string (nullable = true)
#  |-- type: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- coding: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- insurer: struct (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- careTeam: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- role: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- provider: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- reference: string (nullable = true)
#  |-- created: string (nullable = true)
#  |-- item: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- locationCodeableConcept: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- productOrService: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |-- encounter: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- category: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- servicedPeriod: struct (nullable = true)
#  |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- end: string (nullable = true)
#  |    |    |-- adjudication: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |    |-- double: double (nullable = true)
#  |    |    |    |    |    |    |-- long: long (nullable = true)
#  |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- informationSequence: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |    |    |-- net: struct (nullable = true)
#  |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |-- double: double (nullable = true)
#  |    |    |    |    |-- long: long (nullable = true)
#  |    |    |-- diagnosisSequence: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |    |    |-- procedureSequence: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |-- supportingInfo: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- valueReference: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- category: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |-- priority: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |-- author: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- subject: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- context: struct (nullable = true)
#  |    |-- period: struct (nullable = true)
#  |    |    |-- start: string (nullable = true)
#  |    |    |-- end: string (nullable = true)
#  |    |-- encounter: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |-- custodian: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- content: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachment: struct (nullable = true)
#  |    |    |    |-- data: string (nullable = true)
#  |    |    |    |-- contentType: string (nullable = true)
#  |    |    |-- format: struct (nullable = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |-- category: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- coding: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- verificationStatus: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |-- clinicalStatus: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |-- recordedDate: string (nullable = true)
#  |-- code: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- onsetDateTime: string (nullable = true)
#  |-- facility: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- participant: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- period: struct (nullable = true)
#  |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- end: string (nullable = true)
#  |    |    |-- individual: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |    |-- type: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- role: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- member: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |-- serviceProvider: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- class: struct (nullable = true)
#  |    |-- system: string (nullable = true)
#  |    |-- code: string (nullable = true)
#  |-- period: struct (nullable = true)
#  |    |-- start: string (nullable = true)
#  |    |-- end: string (nullable = true)
#  |-- presentedForm: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- data: string (nullable = true)
#  |    |    |-- contentType: string (nullable = true)
#  |-- issued: string (nullable = true)
#  |-- effectiveDateTime: string (nullable = true)
#  |-- performer: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- name: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- given: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- prefix: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- family: string (nullable = true)
#  |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |-- string: string (nullable = true)
#  |-- address: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- country: string (nullable = true)
#  |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- valueDecimal: double (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- city: string (nullable = true)
#  |    |    |    |-- line: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- district: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- line: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- postalCode: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |-- active: boolean (nullable = true)
#  |-- extension: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- valueInteger: long (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- valueString: string (nullable = true)
#  |    |    |-- valueAddress: struct (nullable = true)
#  |    |    |    |-- country: string (nullable = true)
#  |    |    |    |-- city: string (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |-- valueDecimal: struct (nullable = true)
#  |    |    |    |-- double: double (nullable = true)
#  |    |    |    |-- long: long (nullable = true)
#  |    |    |-- extension: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- valueCoding: struct (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- valueCode: string (nullable = true)
#  |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |-- diagnosis: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- diagnosisReference: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- type: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |-- performedPeriod: struct (nullable = true)
#  |    |-- start: string (nullable = true)
#  |    |-- end: string (nullable = true)
#  |-- reasonReference: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- communication: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- language: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |-- text: struct (nullable = true)
#  |    |-- div: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |-- birthDate: string (nullable = true)
#  |-- maritalStatus: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- multipleBirthBoolean: boolean (nullable = true)
#  |-- telecom: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- system: string (nullable = true)
#  |    |    |-- use: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |    |    |-- rank: long (nullable = true)
#  |    |    |-- period: struct (nullable = true)
#  |    |    |    |-- end: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- valueQuantity: struct (nullable = true)
#  |    |-- unit: string (nullable = true)
#  |    |-- system: string (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- value: struct (nullable = true)
#  |    |    |-- double: double (nullable = true)
#  |    |    |-- long: long (nullable = true)
#  |-- medicationCodeableConcept: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- intent: string (nullable = true)
#  |-- authoredOn: string (nullable = true)
#  |-- requester: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- procedure: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- procedureReference: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |-- prescription: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- valueCodeableConcept: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- abatementDateTime: string (nullable = true)
#  |-- dosageInstruction: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- asNeededBoolean: boolean (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- timing: struct (nullable = true)
#  |    |    |    |-- repeat: struct (nullable = true)
#  |    |    |    |    |-- period: long (nullable = true)
#  |    |    |    |    |-- periodUnit: string (nullable = true)
#  |    |    |    |    |-- frequency: long (nullable = true)
#  |    |    |-- doseAndRate: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- doseQuantity: struct (nullable = true)
#  |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |-- managingOrganization: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- value: string (nullable = true)
#  |-- component: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- code: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |-- valueQuantity: struct (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- value: long (nullable = true)
#  |-- reasonCode: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- coding: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- activity: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- detail: struct (nullable = true)
#  |    |    |    |-- code: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |-- contentType: string (nullable = true)
#  |-- addresses: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |-- deceasedDateTime: string (nullable = true)
#  |-- agent: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- onBehalfOf: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |    |-- type: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |-- who: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |-- recorded: string (nullable = true)
#  |-- target: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |-- contact: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- period: struct (nullable = true)
#  |    |    |    |-- start: string (nullable = true)
#  |    |    |-- address: struct (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- city: string (nullable = true)
#  |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- line: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- district: string (nullable = true)
#  |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- gender: string (nullable = true)
#  |    |    |-- name: struct (nullable = true)
#  |    |    |    |-- given: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- _family: struct (nullable = true)
#  |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- family: string (nullable = true)
#  |    |    |-- telecom: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- relationship: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |-- deceasedBoolean: boolean (nullable = true)
#  |-- _birthDate: struct (nullable = true)
#  |    |-- extension: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- valueDateTime: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |-- serviceType: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- hospitalization: struct (nullable = true)
#  |    |-- specialArrangement: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- admitSource: struct (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |-- dischargeDisposition: struct (nullable = true)
#  |    |    |-- coding: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- length: struct (nullable = true)
#  |    |-- unit: string (nullable = true)
#  |-- multipleBirthInteger: long (nullable = true)
#  |-- deviceName: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- serialNumber: string (nullable = true)
#  |-- expirationDate: string (nullable = true)
#  |-- udiCarrier: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- deviceIdentifier: string (nullable = true)
#  |    |    |-- carrierHRF: string (nullable = true)
#  |-- manufactureDate: string (nullable = true)
#  |-- distinctIdentifier: string (nullable = true)
#  |-- lotNumber: string (nullable = true)
#  |-- position: struct (nullable = true)
#  |    |-- latitude: double (nullable = true)
#  |    |-- longitude: double (nullable = true)

# %%
conditions = df.filter(df.resourceType=='Condition')
conditions.show(1,truncate= False)
# Out:
# +------------------+---+--------------+------------+-------------+-------------+------------------------------------+-----------------------------+------+-----------+-----------------------------------------------+-------+--------+-----+--------+---------+----------+-------+-----+-------+--------+--------------+---------+----+----+-------+--------+-------+----+--------------+--------+------+-----------------------------------------------------+-------+---------+----+-------+----------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------+------------------------------------------------------------------------+-------------------------+-----------------------------------------------------------------------------------+-------------------------+--------+-----------+---------------+-----+------+-------------+------+-----------------+---------+----+-------+------+---------+---------+---------------+---------------+-------------+----+---------+-------------+--------------------+-------+------+-------------+-------------------------+------+----------+---------+---------+------------+--------------------+-------------------------+-----------------+--------------------+---------+----------+------+--------+-----------+---------+----------------+-----+--------+------+-------+---------------+----------+-----------+---------------+------+--------------------+----------+------------+--------------+----------+---------------+------------------+---------+--------+
# |occurrenceDateTime|vid|documentStatus|resourceType|lockEndTs    |primarySource|id                                  |meta                         |status|vaccineCode|encounter                                      |patient|location|claim|provider|insurance|identifier|outcome|total|payment|referral|billablePeriod|contained|use |type|insurer|careTeam|created|item|supportingInfo|priority|author|subject                                              |context|custodian|date|content|category                                                                                                        |verificationStatus                                                         |clinicalStatus                                                          |recordedDate             |code                                                                               |onsetDateTime            |facility|participant|serviceProvider|class|period|presentedForm|issued|effectiveDateTime|performer|name|address|active|extension|diagnosis|performedPeriod|reasonReference|communication|text|birthDate|maritalStatus|multipleBirthBoolean|telecom|gender|valueQuantity|medicationCodeableConcept|intent|authoredOn|requester|procedure|prescription|valueCodeableConcept|abatementDateTime        |dosageInstruction|managingOrganization|component|reasonCode|result|activity|contentType|addresses|deceasedDateTime|agent|recorded|target|contact|deceasedBoolean|_birthDate|serviceType|hospitalization|length|multipleBirthInteger|deviceName|serialNumber|expirationDate|udiCarrier|manufactureDate|distinctIdentifier|lotNumber|position|
# +------------------+---+--------------+------------+-------------+-------------+------------------------------------+-----------------------------+------+-----------+-----------------------------------------------+-------+--------+-----+--------+---------+----------+-------+-----+-------+--------+--------------+---------+----+----+-------+--------+-------+----+--------------+--------+------+-----------------------------------------------------+-------+---------+----+-------+----------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------+------------------------------------------------------------------------+-------------------------+-----------------------------------------------------------------------------------+-------------------------+--------+-----------+---------------+-----+------+-------------+------+-----------------+---------+----+-------+------+---------+---------+---------------+---------------+-------------+----+---------+-------------+--------------------+-------+------+-------------+-------------------------+------+----------+---------+---------+------------+--------------------+-------------------------+-----------------+--------------------+---------+----------+------+--------+-----------+---------+----------------+-----+--------+------+-------+---------------+----------+-----------+---------------+------+--------------------+----------+------------+--------------+----------+---------------+------------------+---------+--------+
# |null              |1  |AVAILABLE     |Condition   |1614095093895|null         |8f3eeac6-9b0f-4872-a750-64e12495f343|{2021-02-23T15:44:53.895Z, 1}|null  |null       |{urn:uuid:ee997928-a6cd-540b-187a-79e1876192a5}|null   |null    |null |null    |null     |null      |null   |null |null   |null    |null          |null     |null|null|null   |null    |null   |null|null          |null    |null  |{urn:uuid:f71f0e3d-ec58-117a-3475-256887f6b1ae, null}|null   |null     |null|null   |[{[{http://terminology.hl7.org/CodeSystem/condition-category, encounter-diagnosis, Encounter Diagnosis}], null}]|{[{http://terminology.hl7.org/CodeSystem/condition-ver-status, confirmed}]}|{[{http://terminology.hl7.org/CodeSystem/condition-clinical, resolved}]}|2014-10-20T17:51:45+03:00|{[{http://snomed.info/sct, 198992004, Antepartum eclampsia}], Antepartum eclampsia}|2014-10-20T17:51:45+03:00|null    |null       |null           |null |null  |null         |null  |null             |null     |null|null   |null  |null     |null     |null           |null           |null         |null|null     |null         |null                |null   |null  |null         |null                     |null  |null      |null     |null     |null        |null                |2014-11-10T16:51:45+02:00|null             |null                |null     |null      |null  |null    |null       |null     |null            |null |null    |null  |null   |null           |null      |null       |null           |null  |null                |null      |null        |null          |null      |null           |null              |null     |null    |
# +------------------+---+--------------+------------+-------------+-------------+------------------------------------+-----------------------------+------+-----------+-----------------------------------------------+-------+--------+-----+--------+---------+----------+-------+-----+-------+--------+--------------+---------+----+----+-------+--------+-------+----+--------------+--------+------+-----------------------------------------------------+-------+---------+----+-------+----------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------+------------------------------------------------------------------------+-------------------------+-----------------------------------------------------------------------------------+-------------------------+--------+-----------+---------------+-----+------+-------------+------+-----------------+---------+----+-------+------+---------+---------+---------------+---------------+-------------+----+---------+-------------+--------------------+-------+------+-------------+-------------------------+------+----------+---------+---------+------------+--------------------+-------------------------+-----------------+--------------------+---------+----------+------+--------+-----------+---------+----------------+-----+--------+------+-------+---------------+----------+-----------+---------------+------+--------------------+----------+------------+--------------+----------+---------------+------------------+---------+--------+
# only showing top 1 row

# %%
occurence = conditions.select(['id','encounter','clinicalStatus','subject','code','abatementDateTime','onsetDateTime'])
occurence.show(truncate=False)
# Out:
# +------------------------------------+-----------------------------------------------+------------------------------------------------------------------------+-----------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------+-------------------------+-------------------------+
# |id                                  |encounter                                      |clinicalStatus                                                          |subject                                              |code                                                                                                                               |abatementDateTime        |onsetDateTime            |
# +------------------------------------+-----------------------------------------------+------------------------------------------------------------------------+-----------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------+-------------------------+-------------------------+
# |8f3eeac6-9b0f-4872-a750-64e12495f343|{urn:uuid:ee997928-a6cd-540b-187a-79e1876192a5}|{[{http://terminology.hl7.org/CodeSystem/condition-clinical, resolved}]}|{urn:uuid:f71f0e3d-ec58-117a-3475-256887f6b1ae, null}|{[{http://snomed.info/sct, 198992004, Antepartum eclampsia}], Antepartum eclampsia}                                                |2014-11-10T16:51:45+02:00|2014-10-20T17:51:45+03:00|
# |bb6d7193-513a-40df-889f-aa0e1417ba26|{urn:uuid:4e976ccd-2f1b-4a48-9553-6f7135334157}|{[{http://terminology.hl7.org/CodeSystem/condition-clinical, active}]}  |{urn:uuid:f71f0e3d-ec58-117a-3475-256887f6b1ae, null}|{[{http://snomed.info/sct, 59621000, Hypertension}], Hypertension}                                                                 |null                     |1997-09-08T17:51:45+03:00|
# |1b01b5b8-be7c-4e81-91ba-12b2a445af14|{urn:uuid:a44ce864-6f44-71de-a724-58d0f62517c0}|{[{http://terminology.hl7.org/CodeSystem/condition-clinical, resolved}]}|{urn:uuid:91f5a100-27d4-c886-e175-45e85c00b91c, null}|{[{http://snomed.info/sct, 10509002, Acute bronchitis (disorder)}], Acute bronchitis (disorder)}                                   |2017-03-22T13:44:52-12:00|2017-03-15T13:27:52-12:00|
# |3f17931e-a178-4957-887b-fe1fee872b16|{urn:uuid:d29b8016-5348-6962-2331-3ce4affca2fa}|{[{http://terminology.hl7.org/CodeSystem/condition-clinical, resolved}]}|{urn:uuid:46c99701-db47-cf30-c99c-06c71d319a8e, null}|{[{http://snomed.info/sct, 840544004, Suspected COVID-19}], Suspected COVID-19}                                                    |2020-03-07T15:21:57+02:00|2020-03-07T14:25:57+02:00|
# |0e1f9b41-12e3-483f-8bc6-46f778888a15|{urn:uuid:5f76c1e8-d8ca-ad31-aec1-f94307309262}|{[{http://terminology.hl7.org/CodeSystem/condition-clinical, resolved}]}|{urn:uuid:7e6fa50a-e597-5596-8c0e-37fbdaa8d78d, null}|{[{http://snomed.info/sct, 10509002, Acute bronchitis (disorder)}], Acute bronchitis (disorder)}                                   |2011-04-14T19:43:09-12:00|2011-03-31T19:43:09-12:00|
# |390dab7e-9f67-4767-aa12-2c3f57299410|{urn:uuid:d3f52592-a370-97a5-1f4e-a269c7544a40}|{[{http://terminology.hl7.org/CodeSystem/condition-clinical, active}]}  |{urn:uuid:cdb934bb-d4ff-e40c-7fed-fe8887266654, null}|{[{http://snomed.info/sct, 399211009, History of myocardial infarction (situation)}], History of myocardial infarction (situation)}|null                     |1991-06-16T13:02:29+01:00|
# +------------------------------------+-----------------------------------------------+------------------------------------------------------------------------+-----------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------+-------------------------+-------------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import to_date,to_timestamp,hour, minute, second,date_trunc
occ1=occurence\
    .withColumn("encounter",col("encounter.reference").substr(10,47))\
    .withColumn("subject",col("subject.reference").substr(10,47))\
    .withColumn("aDate", col("abatementDateTime").substr(1,10))\
    .withColumn("aDateTime", col("abatementDateTime").substr(12,8))\
    .withColumn("oDate",col("onsetDateTime").substr(1,10))\
    .withColumn("oDateTime",col("onsetDateTime").substr(12,8))\
    .withColumn("clinicalStatus",col("clinicalStatus.coding.code"))\
    .withColumn("code",col("code.coding.code"))
occ1=occ1.drop(col("abatementDateTime"))
occ1=occ1.drop(col("onsetDateTime"))
occ1.show(truncate=False)
# Out:
# +------------------------------------+------------------------------------+--------------+------------------------------------+-----------------+----------+---------+----------+---------+
# |390dab7e-9f67-476...|d3f52592-a370-97a...|        active|cdb934bb-d4ff-e40...|      399211009|      null|          null null|1991-06-16|1991-06-16 13:02:29|
# +--------------------+--------------------+--------------+--------------------+---------------+----------+-------------------+----------+-------------------+
# only showing top 20 rows
#
# root
#  |-- id: string (nullable = true)
#  |-- encounter: string (nullable = true)
#  |-- clinicalStatus: string (nullable = true)
#  |-- subject: string (nullable = true)
#  |-- code: string (nullable = true)
#  |-- aDate: string (nullable = true)
#  |-- aDateTime: string (nullable = false)
#  |-- oDate: string (nullable = true)
#  |-- oDateTime: string (nullable = false)

# %%
occ3 = occ2.withColumn("aDate",to_date(col("aDate")))\
    .withColumn("aDateTime",to_timestamp(col("aDateTime")))\
    .withColumn("oDate",to_date(col("aDate")))\
    .withColumn("oDateTime",to_timestamp(col("oDateTime")))\
    .withColumn("code",col("code").cast("int"))
    
                
occ3.show()
occ3.printSchema()
# Out:
# +--------------------+--------------------+--------------+--------------------+---------+----------+-------------------+----------+-------------------+
# |                  id|           encounter|clinicalStatus|             subject|     code|     aDate|          aDateTime|     oDate|          oDateTime|
# +--------------------+--------------------+--------------+--------------------+---------+----------+-------------------+----------+-------------------+
# |8f3eeac6-9b0f-487...|ee997928-a6cd-540...|      resolved|f71f0e3d-ec58-117...|198992004|2014-11-10|2014-11-10 16:51:45|2014-11-10|2014-10-20 17:51:45|
# |114c3a28-15a2-4fd...|d29b8016-5348-696...|      resolved|46c99701-db47-cf3...| 84229001|2020-03-26|2020-03-26 15:21:57|2020-03-26|2020-03-07 14:25:57|
# |c85c19e6-d19c-4df...|d3f52592-a370-97a...|        active|cdb934bb-d4ff-e40...| 22298006|      null|               null|      null|1991-06-16 13:02:29|
# |422cd290-ff34-43e...|222c29db-3c06-89e...|        active|760fa8ba-9525-a1b...| 49436004|      null|               null|      null|2014-11-22 00:29:37|
# |e6a98a15-8c38-4b4...|d29b8016-5348-696...|      resolved|46c99701-db47-cf3...|840544004|2020-03-07|2020-03-07 15:21:57|2020-03-07|2020-03-07 14:25:57|
# |630f542f-f05a-48a...|d29b8016-5348-696...|      resolved|46c99701-db47-cf3...|840539006|2020-03-26|2020-03-26 15:21:57|2020-03-26|2020-03-07 15:21:57|
# |6a2da0f1-4506-4a4...|de67ca02-a663-642...|        active|f71f0e3d-ec58-117...|     null|      null|               null|      null|1993-09-17 17:51:45|
# |c4b1d116-51d9-438...|7be0acde-b3f9-5c7...|        active|f7e1b676-472a-77e...|230690007|      null|               null|      null|2001-12-11 00:59:02|
# |7051df3c-ff14-4b9...|9cccd83c-c03b-064...|      resolved|d91d0bf0-2f17-778...| 10509002|2018-08-24|2018-08-24 10:34:45|2018-08-24|2018-08-10 10:20:45|
# |8105524c-9e2a-48f...|ea3b7b0a-5dd4-085...|      resolved|ce95a00e-a107-61b...| 10509002|2014-01-30|2014-01-30 22:56:53|2014-01-30|2014-01-23 22:42:53|
# |46368627-9ce6-473...|f8e84da2-1bd7-74f...|      resolved|46c99701-db47-cf3...|195662009|2011-06-12|2011-06-12 15:25:57|2011-06-12|2011-05-30 15:25:57|
# |f6fe790d-d88a-43d...|cf8a1ab3-58c9-6fa...|        active|f71f0e3d-ec58-117...| 55680006|      null|               null|      null|2007-02-28 16:51:45|
# |e6d4fe73-1936-4a4...|d29b8016-5348-696...|      resolved|46c99701-db47-cf3...|840539006|2020-03-26|2020-03-26 15:21:57|2020-03-26|2020-03-07 15:21:57|
# |b31b2cc4-8d8f-4ea...|d29b8016-5348-696...|      resolved|46c99701-db47-cf3...| 49727002|2020-03-26|2020-03-26 15:21:57|2020-03-26|2020-03-07 14:25:57|
# |f5593b08-698e-4b3...|f8e84da2-1bd7-74f...|      resolved|46c99701-db47-cf3...|195662009|2011-06-12|2011-06-12 15:25:57|2011-06-12|2011-05-30 15:25:57|
# |bb6d7193-513a-40d...|4e976ccd-2f1b-4a4...|        active|f71f0e3d-ec58-117...| 59621000|      null|               null|      null|1997-09-08 17:51:45|
# |1b01b5b8-be7c-4e8...|a44ce864-6f44-71d...|      resolved|91f5a100-27d4-c88...| 10509002|2017-03-22|2017-03-22 13:44:52|2017-03-22|2017-03-15 13:27:52|
# |3f17931e-a178-495...|d29b8016-5348-696...|      resolved|46c99701-db47-cf3...|840544004|2020-03-07|2020-03-07 15:21:57|2020-03-07|2020-03-07 14:25:57|
# |0e1f9b41-12e3-483...|5f76c1e8-d8ca-ad3...|      resolved|7e6fa50a-e597-559...| 10509002|2011-04-14|2011-04-14 19:43:09|2011-04-14|2011-03-31 19:43:09|
# |390dab7e-9f67-476...|d3f52592-a370-97a...|        active|cdb934bb-d4ff-e40...|399211009|      null|               null|      null|1991-06-16 13:02:29|
# +--------------------+--------------------+--------------+--------------------+---------+----------+-------------------+----------+-------------------+
# only showing top 20 rows
#
# root
#  |-- id: string (nullable = true)
#  |-- encounter: string (nullable = true)
#  |-- clinicalStatus: string (nullable = true)
#  |-- subject: string (nullable = true)
#  |-- code: integer (nullable = true)
#  |-- aDate: date (nullable = true)
#  |-- aDateTime: timestamp (nullable = true)
#  |-- oDate: date (nullable = true)
#  |-- oDateTime: timestamp (nullable = true)

# %%
occ4=occ3.withColumnRenamed("id","condition_occurence_id")\
    .withColumnRenamed("encounter","visit_occurence_id")\
    .withColumnRenamed("clinicalStatus","condition_status_concept_id")\
    .withColumnRenamed("subject","person_id")\
    .withColumnRenamed("code","condition_concept_id")\
    .withColumnRenamed("aDate","condition_start_date")\
    .withColumnRenamed("aDateTime","condition_start_datetime")\
    .withColumnRenamed("oDate","condition_end_date")\
    .withColumnRenamed("oDateTime","condition_end_datetime")
occ4.show()
# Out:
# +----------------------+--------------------+---------------------------+--------------------+--------------------+--------------------+------------------------+------------------+----------------------+
# |condition_occurence_id|  visit_occurence_id|condition_status_concept_id|           person_id|condition_concept_id|condition_start_date|condition_start_datetime|condition_end_date|condition_end_datetime|
# +----------------------+--------------------+---------------------------+--------------------+--------------------+--------------------+------------------------+------------------+----------------------+
# |  8f3eeac6-9b0f-487...|ee997928-a6cd-540...|                   resolved|f71f0e3d-ec58-117...|           198992004|          2014-11-10|     2014-11-10 16:51:45|        2014-11-10|   2014-10-20 17:51:45|
# |  3f17931e-a178-495...|d29b8016-5348-696...|                   resolved|46c99701-db47-cf3...|           840544004|          2020-03-07|     2020-03-07 15:21:57|        2020-03-07|   2020-03-07 14:25:57|
# |  0e1f9b41-12e3-483...|5f76c1e8-d8ca-ad3...|                   resolved|7e6fa50a-e597-559...|            10509002|          2011-04-14|     2011-04-14 19:43:09|        2011-04-14|   2011-03-31 19:43:09|
# |  390dab7e-9f67-476...|d3f52592-a370-97a...|                     active|cdb934bb-d4ff-e40...|           399211009|                null|                    null|              null|   1991-06-16 13:02:29|
# +----------------------+--------------------+---------------------------+--------------------+--------------------+--------------------+------------------------+------------------+----------------------+
# only showing top 20 rows

# %%
provider = df.filter(df['resourceType'] == 'Practitioner')
provider.printSchema()
# Out:
# root
#  |-- occurrenceDateTime: string (nullable = true)
#  |-- vid: long (nullable = true)
#  |-- documentStatus: string (nullable = true)
#  |-- resourceType: string (nullable = true)
#  |-- lockEndTs: long (nullable = true)
#  |-- primarySource: boolean (nullable = true)
#  |-- id: string (nullable = true)
#  |-- meta: struct (nullable = true)
#  |    |-- lastUpdated: string (nullable = true)
#  |    |-- versionId: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- vaccineCode: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- encounter: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- patient: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- location: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- claim: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- provider: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- insurance: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- coverage: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |    |-- focal: boolean (nullable = true)
#  |    |    |-- sequence: long (nullable = true)
#  |-- identifier: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- system: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |    |    |-- type: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |-- use: string (nullable = true)
#  |    |    |-- period: struct (nullable = true)
#  |    |    |    |-- start: string (nullable = true)
#  |    |    |-- assigner: struct (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |    |-- extension: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |-- outcome: string (nullable = true)
#  |-- total: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |-- double: double (nullable = true)
#  |    |    |    |    |    |-- long: long (nullable = true)
#  |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- currency: string (nullable = true)
#  |    |    |-- value: struct (nullable = true)
#  |    |    |    |-- double: double (nullable = true)
#  |    |    |    |-- long: long (nullable = true)
#  |-- payment: struct (nullable = true)
#  |    |-- amount: struct (nullable = true)
#  |    |    |-- currency: string (nullable = true)
#  |    |    |-- value: struct (nullable = true)
#  |    |    |    |-- double: double (nullable = true)
#  |    |    |    |-- long: long (nullable = true)
#  |-- referral: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- billablePeriod: struct (nullable = true)
#  |    |-- start: string (nullable = true)
#  |    |-- end: string (nullable = true)
#  |-- contained: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- requester: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- performer: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- subject: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- intent: string (nullable = true)
#  |    |    |-- resourceType: string (nullable = true)
#  |    |    |-- status: string (nullable = true)
#  |    |    |-- payor: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- beneficiary: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- type: struct (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |-- use: string (nullable = true)
#  |-- type: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- coding: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- insurer: struct (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- careTeam: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- role: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- provider: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- reference: string (nullable = true)
#  |-- created: string (nullable = true)
#  |-- item: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- locationCodeableConcept: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- productOrService: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |-- encounter: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- category: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- servicedPeriod: struct (nullable = true)
#  |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- end: string (nullable = true)
#  |    |    |-- adjudication: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |    |    |-- double: double (nullable = true)
#  |    |    |    |    |    |    |-- long: long (nullable = true)
#  |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- informationSequence: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |    |    |-- net: struct (nullable = true)
#  |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |-- value: struct (nullable = true)
#  |    |    |    |    |-- double: double (nullable = true)
#  |    |    |    |    |-- long: long (nullable = true)
#  |    |    |-- diagnosisSequence: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |    |    |-- procedureSequence: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |-- supportingInfo: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- valueReference: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- category: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |-- priority: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |-- author: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- subject: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- context: struct (nullable = true)
#  |    |-- period: struct (nullable = true)
#  |    |    |-- start: string (nullable = true)
#  |    |    |-- end: string (nullable = true)
#  |    |-- encounter: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |-- custodian: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- content: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachment: struct (nullable = true)
#  |    |    |    |-- data: string (nullable = true)
#  |    |    |    |-- contentType: string (nullable = true)
#  |    |    |-- format: struct (nullable = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |-- category: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- coding: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- verificationStatus: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |-- clinicalStatus: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |-- recordedDate: string (nullable = true)
#  |-- code: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- onsetDateTime: string (nullable = true)
#  |-- facility: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- participant: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- period: struct (nullable = true)
#  |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- end: string (nullable = true)
#  |    |    |-- individual: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |    |-- type: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- role: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- member: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |-- serviceProvider: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- class: struct (nullable = true)
#  |    |-- system: string (nullable = true)
#  |    |-- code: string (nullable = true)
#  |-- period: struct (nullable = true)
#  |    |-- start: string (nullable = true)
#  |    |-- end: string (nullable = true)
#  |-- presentedForm: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- data: string (nullable = true)
#  |    |    |-- contentType: string (nullable = true)
#  |-- issued: string (nullable = true)
#  |-- effectiveDateTime: string (nullable = true)
#  |-- performer: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- name: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- given: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- prefix: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- family: string (nullable = true)
#  |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |-- string: string (nullable = true)
#  |-- address: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- country: string (nullable = true)
#  |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- valueDecimal: double (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- city: string (nullable = true)
#  |    |    |    |-- line: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- district: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- line: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- postalCode: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |-- active: boolean (nullable = true)
#  |-- extension: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- valueInteger: long (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- valueString: string (nullable = true)
#  |    |    |-- valueAddress: struct (nullable = true)
#  |    |    |    |-- country: string (nullable = true)
#  |    |    |    |-- city: string (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |-- valueDecimal: struct (nullable = true)
#  |    |    |    |-- double: double (nullable = true)
#  |    |    |    |-- long: long (nullable = true)
#  |    |    |-- extension: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- valueCoding: struct (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- valueCode: string (nullable = true)
#  |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |-- diagnosis: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- diagnosisReference: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- type: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |-- performedPeriod: struct (nullable = true)
#  |    |-- start: string (nullable = true)
#  |    |-- end: string (nullable = true)
#  |-- reasonReference: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- communication: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- language: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |-- text: struct (nullable = true)
#  |    |-- div: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |-- birthDate: string (nullable = true)
#  |-- maritalStatus: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- multipleBirthBoolean: boolean (nullable = true)
#  |-- telecom: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- system: string (nullable = true)
#  |    |    |-- use: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |    |    |-- rank: long (nullable = true)
#  |    |    |-- period: struct (nullable = true)
#  |    |    |    |-- end: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- valueQuantity: struct (nullable = true)
#  |    |-- unit: string (nullable = true)
#  |    |-- system: string (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- value: struct (nullable = true)
#  |    |    |-- double: double (nullable = true)
#  |    |    |-- long: long (nullable = true)
#  |-- medicationCodeableConcept: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- intent: string (nullable = true)
#  |-- authoredOn: string (nullable = true)
#  |-- requester: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |    |-- display: string (nullable = true)
#  |-- procedure: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- procedureReference: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |-- prescription: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- valueCodeableConcept: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- abatementDateTime: string (nullable = true)
#  |-- dosageInstruction: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- asNeededBoolean: boolean (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- timing: struct (nullable = true)
#  |    |    |    |-- repeat: struct (nullable = true)
#  |    |    |    |    |-- period: long (nullable = true)
#  |    |    |    |    |-- periodUnit: string (nullable = true)
#  |    |    |    |    |-- frequency: long (nullable = true)
#  |    |    |-- doseAndRate: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- doseQuantity: struct (nullable = true)
#  |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |-- managingOrganization: struct (nullable = true)
#  |    |-- array: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- struct: struct (nullable = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- value: string (nullable = true)
#  |-- component: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- code: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |-- valueQuantity: struct (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- value: long (nullable = true)
#  |-- reasonCode: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- coding: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |-- activity: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- detail: struct (nullable = true)
#  |    |    |    |-- code: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |-- contentType: string (nullable = true)
#  |-- addresses: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |-- deceasedDateTime: string (nullable = true)
#  |-- agent: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- onBehalfOf: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |    |-- type: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |-- who: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |-- recorded: string (nullable = true)
#  |-- target: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- reference: string (nullable = true)
#  |-- contact: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- period: struct (nullable = true)
#  |    |    |    |-- start: string (nullable = true)
#  |    |    |-- address: struct (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- city: string (nullable = true)
#  |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- line: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- district: string (nullable = true)
#  |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- gender: string (nullable = true)
#  |    |    |-- name: struct (nullable = true)
#  |    |    |    |-- given: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- _family: struct (nullable = true)
#  |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- family: string (nullable = true)
#  |    |    |-- telecom: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- relationship: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |-- deceasedBoolean: boolean (nullable = true)
#  |-- _birthDate: struct (nullable = true)
#  |    |-- extension: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- valueDateTime: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |-- serviceType: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- display: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- hospitalization: struct (nullable = true)
#  |    |-- specialArrangement: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- admitSource: struct (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |-- dischargeDisposition: struct (nullable = true)
#  |    |    |-- coding: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- length: struct (nullable = true)
#  |    |-- unit: string (nullable = true)
#  |-- multipleBirthInteger: long (nullable = true)
#  |-- deviceName: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- serialNumber: string (nullable = true)
#  |-- expirationDate: string (nullable = true)
#  |-- udiCarrier: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- deviceIdentifier: string (nullable = true)
#  |    |    |-- carrierHRF: string (nullable = true)
#  |-- manufactureDate: string (nullable = true)
#  |-- distinctIdentifier: string (nullable = true)
#  |-- lotNumber: string (nullable = true)
#  |-- position: struct (nullable = true)
#  |    |-- latitude: double (nullable = true)
#  |    |-- longitude: double (nullable = true)

# %%
provider.show(2,truncate=False)
# Out:
# +------------------+---+--------------+------------+-------------+-------------+------------------------------------+-----------------------------+------+-----------+---------+-------+--------+-----+--------+---------+----------------------------------------------------------------------------+-------+-----+-------+--------+--------------+---------+----+----+-------+--------+-------+----+--------------+--------+------+-------+-------+---------+----+-------+--------+------------------+--------------+------------+----+-------------+--------+-----------+---------------+-----+------+-------------+------+-----------------+---------+------------------------------------------------------+-------------------------------------------------------------------------------------------------------+------+---------------------------------------------------------------------------------------------------------------------+---------+---------------+---------------+-------------+----+---------+-------------+--------------------+-------------------------------------------------------------+------+-------------+-------------------------+------+----------+---------+---------+------------+--------------------+-----------------+-----------------+--------------------+---------+----------+------+--------+-----------+---------+----------------+-----+--------+------+-------+---------------+----------+-----------+---------------+------+--------------------+----------+------------+--------------+----------+---------------+------------------+---------+--------+
# |occurrenceDateTime|vid|documentStatus|resourceType|lockEndTs    |primarySource|id                                  |meta                         |status|vaccineCode|encounter|patient|location|claim|provider|insurance|identifier                                                                  |outcome|total|payment|referral|billablePeriod|contained|use |type|insurer|careTeam|created|item|supportingInfo|priority|author|subject|context|custodian|date|content|category|verificationStatus|clinicalStatus|recordedDate|code|onsetDateTime|facility|participant|serviceProvider|class|period|presentedForm|issued|effectiveDateTime|performer|name                                                  |address                                                                                                |active|extension                                                                                                            |diagnosis|performedPeriod|reasonReference|communication|text|birthDate|maritalStatus|multipleBirthBoolean|telecom                                                      |gender|valueQuantity|medicationCodeableConcept|intent|authoredOn|requester|procedure|prescription|valueCodeableConcept|abatementDateTime|dosageInstruction|managingOrganization|component|reasonCode|result|activity|contentType|addresses|deceasedDateTime|agent|recorded|target|contact|deceasedBoolean|_birthDate|serviceType|hospitalization|length|multipleBirthInteger|deviceName|serialNumber|expirationDate|udiCarrier|manufactureDate|distinctIdentifier|lotNumber|position|
# +------------------+---+--------------+------------+-------------+-------------+------------------------------------+-----------------------------+------+-----------+---------+-------+--------+-----+--------+---------+----------------------------------------------------------------------------+-------+-----+-------+--------+--------------+---------+----+----+-------+--------+-------+----+--------------+--------+------+-------+-------+---------+----+-------+--------+------------------+--------------+------------+----+-------------+--------+-----------+---------------+-----+------+-------------+------+-----------------+---------+------------------------------------------------------+-------------------------------------------------------------------------------------------------------+------+---------------------------------------------------------------------------------------------------------------------+---------+---------------+---------------+-------------+----+---------+-------------+--------------------+-------------------------------------------------------------+------+-------------+-------------------------+------+----------+---------+---------+------------+--------------------+-----------------+-----------------+--------------------+---------+----------+------+--------+-----------+---------+----------------+-----+--------+------+-------+---------------+----------+-----------+---------------+------+--------------------+----------+------------+--------------+----------+---------------+------------------+---------+--------+
# |null              |1  |AVAILABLE     |Practitioner|1613934710598|null         |b8e3bcc9-cc2d-4f3f-8839-cd759b45b2a5|{2021-02-21T19:11:50.598Z, 1}|null  |null       |null     |null   |null    |null |null    |null     |[{http://hl7.org/fhir/sid/us-npi, 9999999469, null, null, null, null, null}]|null   |null |null   |null    |null          |null     |null|null|null   |null    |null   |null|null          |null    |null  |null   |null   |null     |null|null   |null    |null              |null          |null        |null|null         |null    |null       |null           |null |null  |null         |null  |null             |null     |{[{[Alta896], [Dr.], Schiller186, null, null}], null} |{[{GB, null, Cambridge, [High Street 204], CB1 9, Cambridgeshire, null, null, null, null, null}], null}|true  |[{2, http://synthetichealth.github.io/synthea/utilization-encounters-extension, null, null, null, null, null, null}] |null     |null           |null           |null         |null|null     |null         |null                |[{email, work, Alta896.Schiller186@example.com, null, null}] |female|null         |null                     |null  |null      |null     |null     |null        |null                |null             |null             |null                |null     |null      |null  |null    |null       |null     |null            |null |null    |null  |null   |null           |null      |null       |null           |null  |null                |null      |null        |null          |null      |null           |null              |null     |null    |
# |null              |1  |AVAILABLE     |Practitioner|1614094985118|null         |0147a864-b8c0-4bf7-b07b-0ad711932228|{2021-02-23T15:43:04.958Z, 1}|null  |null       |null     |null   |null    |null |null    |null     |[{http://hl7.org/fhir/sid/us-npi, 9999999409, null, null, null, null, null}]|null   |null |null   |null    |null          |null     |null|null|null   |null    |null   |null|null          |null    |null  |null   |null   |null     |null|null   |null    |null              |null          |null        |null|null         |null    |null       |null           |null |null  |null         |null  |null             |null     |{[{[Shirl54], [Dr.], Ankunding277, null, null}], null}|{[{GB, null, Newport, null, TF10 7, Shropshire, null, null, null, null, null}], null}                  |true  |[{53, http://synthetichealth.github.io/synthea/utilization-encounters-extension, null, null, null, null, null, null}]|null     |null           |null           |null         |null|null     |null         |null                |[{email, work, Shirl54.Ankunding277@example.com, null, null}]|female|null         |null                     |null  |null      |null     |null     |null        |null                |null             |null             |null                |null     |null      |null  |null    |null       |null     |null            |null |null    |null  |null   |null           |null      |null       |null           |null  |null                |null      |null        |null          |null      |null           |null              |null     |null    |
# +------------------+---+--------------+------------+-------------+-------------+------------------------------------+-----------------------------+------+-----------+---------+-------+--------+-----+--------+---------+----------------------------------------------------------------------------+-------+-----+-------+--------+--------------+---------+----+----+-------+--------+-------+----+--------------+--------+------+-------+-------+---------+----+-------+--------+------------------+--------------+------------+----+-------------+--------+-----------+---------------+-----+------+-------------+------+-----------------+---------+------------------------------------------------------+-------------------------------------------------------------------------------------------------------+------+---------------------------------------------------------------------------------------------------------------------+---------+---------------+---------------+-------------+----+---------+-------------+--------------------+-------------------------------------------------------------+------+-------------+-------------------------+------+----------+---------+---------+------------+--------------------+-----------------+-----------------+--------------------+---------+----------+------+--------+-----------+---------+----------------+-----+--------+------+-------+---------------+----------+-----------+---------------+------+--------------------+----------+------------+--------------+----------+---------------+------------------+---------+--------+
# only showing top 2 rows
